# %% [markdown]
# <h2 style='color:blue' align='center'>Sports Celebrity Image Classification<h2>

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:purple'>(1) Preprocessing: Detect face and eyes</h3>

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.</h4>

# %% [markdown]
# #### Now how do you detect face and eyes?

# %%
img = cv2.imread('./test_images/virat.jpg')
img.shape
# Out:
# (900, 1200, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (900, 1200)

# %%
gray
# Out:
# array([[164, 158, 154, ...,  38,  44,  53],
#        [158, 151, 147, ...,  24,  30,  40],
#        [155, 148, 144, ...,  21,  27,  37],
#        ...,
#        [206, 204, 202, ..., 149, 153, 160],
#        [209, 206, 204, ..., 149, 153, 160],
#        [210, 207, 205, ..., 153, 157, 164]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[328, 163, 374, 374]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (328, 163, 374, 374)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:purple'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (374, 374, 3)

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# ### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    c=pywt.wavedec2(imArray, mode, level=level)

    c[0] /= np.abs(c[0]).max()
    for detail_level in range(level):
        c[detail_level + 1] = [d/np.abs(d).max() for d in c[detail_level + 1]]
    # show the normalized coefficients
    arr, slices = pywt.coeffs_to_array(c)
    return arr

# %%
im_har = w2d(cropped_img,'db1',3)
plt.imshow(im_har, cmap='gray')

# %%
im_har.shape
# Out:
# (375, 375)

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    cropped_faces = []
    for (x,y,w,h) in faces:
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)
            if len(eyes) >= 2:
                cropped_faces.append(roi_color)
    return cropped_faces

# %%
original_image = cv2.imread('./test_images/virat3.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/virat3.jpg')
if cropped_image:
    plt.imshow(cropped_image[1])

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/lionel_messi',
#  './dataset/maria_sharapova',
#  './dataset/roger_federer',
#  './dataset/serena_williams',
#  './dataset/virat_kohli']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            for roi_color_per in roi_color:
                cropped_folder = path_to_cr_data + celebrity_name
                if not os.path.exists(cropped_folder):
                    os.makedirs(cropped_folder)
                    cropped_image_dirs.append(cropped_folder)
                    print("Generating cropped images in folder: ",cropped_folder)
                cropped_file_name = celebrity_name + str(count) + ".png"
                cropped_file_path = cropped_folder + "/" + cropped_file_name
                cv2.imwrite(cropped_file_path, roi_color_per)
                print("Done",cropped_file_path)
                celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
                count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/lionel_messi
# Done ./dataset/cropped/lionel_messi/lionel_messi1.png
# Done ./dataset/cropped/lionel_messi/lionel_messi2.png
# Done ./dataset/cropped/lionel_messi/lionel_messi3.png
# Done ./dataset/cropped/lionel_messi/lionel_messi4.png
# Done ./dataset/cropped/lionel_messi/lionel_messi5.png
# Done ./dataset/cropped/lionel_messi/lionel_messi6.png
# Done ./dataset/cropped/lionel_messi/lionel_messi7.png
# Done ./dataset/cropped/lionel_messi/lionel_messi8.png
# Done ./dataset/cropped/lionel_messi/lionel_messi9.png
# Done ./dataset/cropped/lionel_messi/lionel_messi10.png
# Done ./dataset/cropped/lionel_messi/lionel_messi11.png
# Done ./dataset/cropped/lionel_messi/lionel_messi12.png
# Done ./dataset/cropped/lionel_messi/lionel_messi13.png
# Done ./dataset/cropped/lionel_messi/lionel_messi14.png
# Done ./dataset/cropped/lionel_messi/lionel_messi15.png
# Done ./dataset/cropped/lionel_messi/lionel_messi16.png
# Done ./dataset/cropped/lionel_messi/lionel_messi17.png
# Done ./dataset/cropped/lionel_messi/lionel_messi18.png
# Done ./dataset/cropped/lionel_messi/lionel_messi19.png
# Done ./dataset/cropped/lionel_messi/lionel_messi20.png
# Done ./dataset/cropped/lionel_messi/lionel_messi21.png
# Done ./dataset/cropped/lionel_messi/lionel_messi22.png
# Done ./dataset/cropped/lionel_messi/lionel_messi23.png
# Done ./dataset/cropped/lionel_messi/lionel_messi24.png
# Done ./dataset/cropped/lionel_messi/lionel_messi25.png
# Done ./dataset/cropped/lionel_messi/lionel_messi26.png
# Done ./dataset/cropped/lionel_messi/lionel_messi27.png
# Done ./dataset/cropped/lionel_messi/lionel_messi28.png
# Done ./dataset/cropped/lionel_messi/lionel_messi29.png
# Done ./dataset/cropped/lionel_messi/lionel_messi30.png
# Done ./dataset/cropped/lionel_messi/lionel_messi31.png
# Done ./dataset/cropped/lionel_messi/lionel_messi32.png
# Done ./dataset/cropped/lionel_messi/lionel_messi33.png
# Done ./dataset/cropped/lionel_messi/lionel_messi34.png
# Done ./dataset/cropped/lionel_messi/lionel_messi35.png
# Done ./dataset/cropped/lionel_messi/lionel_messi36.png
# Done ./dataset/cropped/lionel_messi/lionel_messi37.png
# Done ./dataset/cropped/lionel_messi/lionel_messi38.png
# Done ./dataset/cropped/lionel_messi/lionel_messi39.png
# Done ./dataset/cropped/lionel_messi/lionel_messi40.png
# Done ./dataset/cropped/lionel_messi/lionel_messi41.png
# Done ./dataset/cropped/lionel_messi/lionel_messi42.png
# Done ./dataset/cropped/lionel_messi/lionel_messi43.png
# Done ./dataset/cropped/lionel_messi/lionel_messi44.png
# Done ./dataset/cropped/lionel_messi/lionel_messi45.png
# Done ./dataset/cropped/lionel_messi/lionel_messi46.png
# Generating cropped images in folder:  ./dataset/cropped/maria_sharapova
# Done ./dataset/cropped/maria_sharapova/maria_sharapova1.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova2.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova3.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova4.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova5.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova6.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova7.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova8.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova9.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova10.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova11.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova12.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova13.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova14.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova15.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova16.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova17.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova18.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova19.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova20.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova21.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova22.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova23.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova24.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova25.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova26.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova27.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova28.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova29.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova30.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova31.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova32.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova33.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova34.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova35.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova36.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova37.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova38.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova39.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova40.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova41.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova42.png
# Done ./dataset/cropped/maria_sharapova/maria_sharapova43.png
# Generating cropped images in folder:  ./dataset/cropped/roger_federer
# Done ./dataset/cropped/roger_federer/roger_federer1.png
# Done ./dataset/cropped/roger_federer/roger_federer2.png
# Done ./dataset/cropped/roger_federer/roger_federer3.png
# Done ./dataset/cropped/roger_federer/roger_federer4.png
# Done ./dataset/cropped/roger_federer/roger_federer5.png
# Done ./dataset/cropped/roger_federer/roger_federer6.png
# Done ./dataset/cropped/roger_federer/roger_federer7.png
# Done ./dataset/cropped/roger_federer/roger_federer8.png
# Done ./dataset/cropped/roger_federer/roger_federer9.png
# Done ./dataset/cropped/roger_federer/roger_federer10.png
# Done ./dataset/cropped/roger_federer/roger_federer11.png
# Done ./dataset/cropped/roger_federer/roger_federer12.png
# Done ./dataset/cropped/roger_federer/roger_federer13.png
# Done ./dataset/cropped/roger_federer/roger_federer14.png
# Done ./dataset/cropped/roger_federer/roger_federer15.png
# Done ./dataset/cropped/roger_federer/roger_federer16.png
# Done ./dataset/cropped/roger_federer/roger_federer17.png
# Done ./dataset/cropped/roger_federer/roger_federer18.png
# Done ./dataset/cropped/roger_federer/roger_federer19.png
# Done ./dataset/cropped/roger_federer/roger_federer20.png
# Done ./dataset/cropped/roger_federer/roger_federer21.png
# Done ./dataset/cropped/roger_federer/roger_federer22.png
# Done ./dataset/cropped/roger_federer/roger_federer23.png
# Done ./dataset/cropped/roger_federer/roger_federer24.png
# Done ./dataset/cropped/roger_federer/roger_federer25.png
# Done ./dataset/cropped/roger_federer/roger_federer26.png
# Done ./dataset/cropped/roger_federer/roger_federer27.png
# Done ./dataset/cropped/roger_federer/roger_federer28.png
# Done ./dataset/cropped/roger_federer/roger_federer29.png
# Done ./dataset/cropped/roger_federer/roger_federer30.png
# Done ./dataset/cropped/roger_federer/roger_federer31.png
# Done ./dataset/cropped/roger_federer/roger_federer32.png
# Done ./dataset/cropped/roger_federer/roger_federer33.png
# Done ./dataset/cropped/roger_federer/roger_federer34.png
# Done ./dataset/cropped/roger_federer/roger_federer35.png
# Done ./dataset/cropped/roger_federer/roger_federer36.png
# Generating cropped images in folder:  ./dataset/cropped/serena_williams
# Done ./dataset/cropped/serena_williams/serena_williams1.png
# Done ./dataset/cropped/serena_williams/serena_williams2.png
# Done ./dataset/cropped/serena_williams/serena_williams3.png
# Done ./dataset/cropped/serena_williams/serena_williams4.png
# Done ./dataset/cropped/serena_williams/serena_williams5.png
# Done ./dataset/cropped/serena_williams/serena_williams6.png
# Done ./dataset/cropped/serena_williams/serena_williams7.png
# Done ./dataset/cropped/serena_williams/serena_williams8.png
# Done ./dataset/cropped/serena_williams/serena_williams9.png
# Done ./dataset/cropped/serena_williams/serena_williams10.png
# Done ./dataset/cropped/serena_williams/serena_williams11.png
# Done ./dataset/cropped/serena_williams/serena_williams12.png
# Done ./dataset/cropped/serena_williams/serena_williams13.png
# Done ./dataset/cropped/serena_williams/serena_williams14.png
# Done ./dataset/cropped/serena_williams/serena_williams15.png
# Done ./dataset/cropped/serena_williams/serena_williams16.png
# Done ./dataset/cropped/serena_williams/serena_williams17.png
# Done ./dataset/cropped/serena_williams/serena_williams18.png
# Done ./dataset/cropped/serena_williams/serena_williams19.png
# Done ./dataset/cropped/serena_williams/serena_williams20.png
# Done ./dataset/cropped/serena_williams/serena_williams21.png
# Generating cropped images in folder:  ./dataset/cropped/virat_kohli
# Done ./dataset/cropped/virat_kohli/virat_kohli1.png
# Done ./dataset/cropped/virat_kohli/virat_kohli2.png
# Done ./dataset/cropped/virat_kohli/virat_kohli3.png
# Done ./dataset/cropped/virat_kohli/virat_kohli4.png
# Done ./dataset/cropped/virat_kohli/virat_kohli5.png
# Done ./dataset/cropped/virat_kohli/virat_kohli6.png
# Done ./dataset/cropped/virat_kohli/virat_kohli7.png
# Done ./dataset/cropped/virat_kohli/virat_kohli8.png
# Done ./dataset/cropped/virat_kohli/virat_kohli9.png
# Done ./dataset/cropped/virat_kohli/virat_kohli10.png
# Done ./dataset/cropped/virat_kohli/virat_kohli11.png
# Done ./dataset/cropped/virat_kohli/virat_kohli12.png
# Done ./dataset/cropped/virat_kohli/virat_kohli13.png
# Done ./dataset/cropped/virat_kohli/virat_kohli14.png
# Done ./dataset/cropped/virat_kohli/virat_kohli15.png
# Done ./dataset/cropped/virat_kohli/virat_kohli16.png
# Done ./dataset/cropped/virat_kohli/virat_kohli17.png
# Done ./dataset/cropped/virat_kohli/virat_kohli18.png
# Done ./dataset/cropped/virat_kohli/virat_kohli19.png
# Done ./dataset/cropped/virat_kohli/virat_kohli20.png
# Done ./dataset/cropped/virat_kohli/virat_kohli21.png
# Done ./dataset/cropped/virat_kohli/virat_kohli22.png
# Done ./dataset/cropped/virat_kohli/virat_kohli23.png
# Done ./dataset/cropped/virat_kohli/virat_kohli24.png
# Done ./dataset/cropped/virat_kohli/virat_kohli25.png
# Done ./dataset/cropped/virat_kohli/virat_kohli26.png
# Done ./dataset/cropped/virat_kohli/virat_kohli27.png
# Done ./dataset/cropped/virat_kohli/virat_kohli28.png
# Done ./dataset/cropped/virat_kohli/virat_kohli29.png
# Done ./dataset/cropped/virat_kohli/virat_kohli30.png
# Done ./dataset/cropped/virat_kohli/virat_kohli31.png
# Done ./dataset/cropped/virat_kohli/virat_kohli32.png
# Done ./dataset/cropped/virat_kohli/virat_kohli33.png
# Done ./dataset/cropped/virat_kohli/virat_kohli34.png
# Done ./dataset/cropped/virat_kohli/virat_kohli35.png
# Done ./dataset/cropped/virat_kohli/virat_kohli36.png
# Done ./dataset/cropped/virat_kohli/virat_kohli37.png
# Done ./dataset/cropped/virat_kohli/virat_kohli38.png
# Done ./dataset/cropped/virat_kohli/virat_kohli39.png
# Done ./dataset/cropped/virat_kohli/virat_kohli40.png
# Done ./dataset/cropped/virat_kohli/virat_kohli41.png
# Done ./dataset/cropped/virat_kohli/virat_kohli42.png
# Done ./dataset/cropped/virat_kohli/virat_kohli43.png
# Done ./dataset/cropped/virat_kohli/virat_kohli44.png
# Done ./dataset/cropped/virat_kohli/virat_kohli45.png
# Done ./dataset/cropped/virat_kohli/virat_kohli46.png
# Done ./dataset/cropped/virat_kohli/virat_kohli47.png
# Done ./dataset/cropped/virat_kohli/virat_kohli48.png
# Done ./dataset/cropped/virat_kohli/virat_kohli49.png
# Done ./dataset/cropped/virat_kohli/virat_kohli50.png
# Done ./dataset/cropped/virat_kohli/virat_kohli51.png
# Done ./dataset/cropped/virat_kohli/virat_kohli52.png
# Done ./dataset/cropped/virat_kohli/virat_kohli53.png
# Done ./dataset/cropped/virat_kohli/virat_kohli54.png
# Done ./dataset/cropped/virat_kohli/virat_kohli55.png

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images

# %%
cropped_image_dirs
# Out:
# ['./dataset/cropped/lionel_messi',
#  './dataset/cropped/maria_sharapova',
#  './dataset/cropped/roger_federer',
#  './dataset/cropped/serena_williams',
#  './dataset/cropped/virat_kohli']

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'lionel_messi': ['./dataset/cropped/lionel_messi\\lionel_messi1.png',
#   './dataset/cropped/lionel_messi\\lionel_messi10.png',
#   './dataset/cropped/lionel_messi\\lionel_messi11.png',
#   './dataset/cropped/lionel_messi\\lionel_messi12.png',
#   './dataset/cropped/lionel_messi\\lionel_messi14.png',
#   './dataset/cropped/lionel_messi\\lionel_messi16.png',
#   './dataset/cropped/lionel_messi\\lionel_messi17.png',
#   './dataset/cropped/lionel_messi\\lionel_messi18.png',
#   './dataset/cropped/lionel_messi\\lionel_messi19.png',
#   './dataset/cropped/lionel_messi\\lionel_messi2.png',
#   './dataset/cropped/lionel_messi\\lionel_messi20.png',
#   './dataset/cropped/lionel_messi\\lionel_messi21.png',
#   './dataset/cropped/lionel_messi\\lionel_messi22.png',
#   './dataset/cropped/lionel_messi\\lionel_messi23.png',
#   './dataset/cropped/lionel_messi\\lionel_messi25.png',
#   './dataset/cropped/lionel_messi\\lionel_messi26.png',
#   './dataset/cropped/lionel_messi\\lionel_messi27.png',
#   './dataset/cropped/lionel_messi\\lionel_messi28.png',
#   './dataset/cropped/lionel_messi\\lionel_messi29.png',
#   './dataset/cropped/lionel_messi\\lionel_messi3.png',
#   './dataset/cropped/lionel_messi\\lionel_messi30.png',
#   './dataset/cropped/lionel_messi\\lionel_messi31.png',
#   './dataset/cropped/lionel_messi\\lionel_messi32.png',
#   './dataset/cropped/lionel_messi\\lionel_messi33.png',
#   './dataset/cropped/lionel_messi\\lionel_messi34.png',
#   './dataset/cropped/lionel_messi\\lionel_messi38.png',
#   './dataset/cropped/lionel_messi\\lionel_messi4.png',
#   './dataset/cropped/lionel_messi\\lionel_messi40.png',
#   './dataset/cropped/lionel_messi\\lionel_messi41.png',
#   './dataset/cropped/lionel_messi\\lionel_messi42.png',
#   './dataset/cropped/lionel_messi\\lionel_messi43.png',
#   './dataset/cropped/lionel_messi\\lionel_messi44.png',
#   './dataset/cropped/lionel_messi\\lionel_messi45.png',
#   './dataset/cropped/lionel_messi\\lionel_messi46.png',
#   './dataset/cropped/lionel_messi\\lionel_messi6.png',
#   './dataset/cropped/lionel_messi\\lionel_messi7.png',
#   './dataset/cropped/lionel_messi\\lionel_messi8.png',
#   './dataset/cropped/lionel_messi\\lionel_messi9.png'],
#  'maria_sharapova': ['./dataset/cropped/maria_sharapova\\maria_sharapova10.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova11.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova13.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova14.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova15.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova17.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova18.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova19.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova2.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova20.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova21.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova22.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova23.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova24.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova25.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova26.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova27.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova28.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova29.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova30.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova31.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova32.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova33.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova34.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova35.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova36.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova37.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova38.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova39.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova40.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova41.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova42.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova43.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova7.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova8.png',
#   './dataset/cropped/maria_sharapova\\maria_sharapova9.png'],
#  'roger_federer': ['./dataset/cropped/roger_federer\\roger_federer1.png',
#   './dataset/cropped/roger_federer\\roger_federer10.png',
#   './dataset/cropped/roger_federer\\roger_federer11.png',
#   './dataset/cropped/roger_federer\\roger_federer12.png',
#   './dataset/cropped/roger_federer\\roger_federer13.png',
#   './dataset/cropped/roger_federer\\roger_federer14.png',
#   './dataset/cropped/roger_federer\\roger_federer15.png',
#   './dataset/cropped/roger_federer\\roger_federer16.png',
#   './dataset/cropped/roger_federer\\roger_federer17.png',
#   './dataset/cropped/roger_federer\\roger_federer18.png',
#   './dataset/cropped/roger_federer\\roger_federer19.png',
#   './dataset/cropped/roger_federer\\roger_federer2.png',
#   './dataset/cropped/roger_federer\\roger_federer20.png',
#   './dataset/cropped/roger_federer\\roger_federer21.png',
#   './dataset/cropped/roger_federer\\roger_federer22.png',
#   './dataset/cropped/roger_federer\\roger_federer23.png',
#   './dataset/cropped/roger_federer\\roger_federer24.png',
#   './dataset/cropped/roger_federer\\roger_federer25.png',
#   './dataset/cropped/roger_federer\\roger_federer26.png',
#   './dataset/cropped/roger_federer\\roger_federer27.png',
#   './dataset/cropped/roger_federer\\roger_federer28.png',
#   './dataset/cropped/roger_federer\\roger_federer29.png',
#   './dataset/cropped/roger_federer\\roger_federer3.png',
#   './dataset/cropped/roger_federer\\roger_federer30.png',
#   './dataset/cropped/roger_federer\\roger_federer31.png',
#   './dataset/cropped/roger_federer\\roger_federer32.png',
#   './dataset/cropped/roger_federer\\roger_federer33.png',
#   './dataset/cropped/roger_federer\\roger_federer34.png',
#   './dataset/cropped/roger_federer\\roger_federer35.png',
#   './dataset/cropped/roger_federer\\roger_federer36.png',
#   './dataset/cropped/roger_federer\\roger_federer4.png',
#   './dataset/cropped/roger_federer\\roger_federer5.png',
#   './dataset/cropped/roger_federer\\roger_federer6.png',
#   './dataset/cropped/roger_federer\\roger_federer7.png',
#   './dataset/cropped/roger_federer\\roger_federer8.png',
#   './dataset/cropped/roger_federer\\roger_federer9.png'],
#  'serena_williams': ['./dataset/cropped/serena_williams\\serena_williams1.png',
#   './dataset/cropped/serena_williams\\serena_williams10.png',
#   './dataset/cropped/serena_williams\\serena_williams11.png',
#   './dataset/cropped/serena_williams\\serena_williams12.png',
#   './dataset/cropped/serena_williams\\serena_williams13.png',
#   './dataset/cropped/serena_williams\\serena_williams14.png',
#   './dataset/cropped/serena_williams\\serena_williams15.png',
#   './dataset/cropped/serena_williams\\serena_williams16.png',
#   './dataset/cropped/serena_williams\\serena_williams17.png',
#   './dataset/cropped/serena_williams\\serena_williams18.png',
#   './dataset/cropped/serena_williams\\serena_williams19.png',
#   './dataset/cropped/serena_williams\\serena_williams2.png',
#   './dataset/cropped/serena_williams\\serena_williams20.png',
#   './dataset/cropped/serena_williams\\serena_williams21.png',
#   './dataset/cropped/serena_williams\\serena_williams3.png',
#   './dataset/cropped/serena_williams\\serena_williams4.png',
#   './dataset/cropped/serena_williams\\serena_williams5.png',
#   './dataset/cropped/serena_williams\\serena_williams6.png',
#   './dataset/cropped/serena_williams\\serena_williams7.png',
#   './dataset/cropped/serena_williams\\serena_williams8.png',
#   './dataset/cropped/serena_williams\\serena_williams9.png'],
#  'virat_kohli': ['./dataset/cropped/virat_kohli\\virat_kohli1.png',
#   './dataset/cropped/virat_kohli\\virat_kohli10.png',
#   './dataset/cropped/virat_kohli\\virat_kohli11.png',
#   './dataset/cropped/virat_kohli\\virat_kohli13.png',
#   './dataset/cropped/virat_kohli\\virat_kohli14.png',
#   './dataset/cropped/virat_kohli\\virat_kohli15.png',
#   './dataset/cropped/virat_kohli\\virat_kohli16.png',
#   './dataset/cropped/virat_kohli\\virat_kohli17.png',
#   './dataset/cropped/virat_kohli\\virat_kohli18.png',
#   './dataset/cropped/virat_kohli\\virat_kohli19.png',
#   './dataset/cropped/virat_kohli\\virat_kohli2.png',
#   './dataset/cropped/virat_kohli\\virat_kohli20.png',
#   './dataset/cropped/virat_kohli\\virat_kohli21.png',
#   './dataset/cropped/virat_kohli\\virat_kohli22.png',
#   './dataset/cropped/virat_kohli\\virat_kohli23.png',
#   './dataset/cropped/virat_kohli\\virat_kohli24.png',
#   './dataset/cropped/virat_kohli\\virat_kohli26.png',
#   './dataset/cropped/virat_kohli\\virat_kohli28.png',
#   './dataset/cropped/virat_kohli\\virat_kohli29.png',
#   './dataset/cropped/virat_kohli\\virat_kohli30.png',
#   './dataset/cropped/virat_kohli\\virat_kohli31.png',
#   './dataset/cropped/virat_kohli\\virat_kohli33.png',
#   './dataset/cropped/virat_kohli\\virat_kohli34.png',
#   './dataset/cropped/virat_kohli\\virat_kohli35.png',
#   './dataset/cropped/virat_kohli\\virat_kohli36.png',
#   './dataset/cropped/virat_kohli\\virat_kohli39.png',
#   './dataset/cropped/virat_kohli\\virat_kohli4.png',
#   './dataset/cropped/virat_kohli\\virat_kohli42.png',
#   './dataset/cropped/virat_kohli\\virat_kohli43.png',
#   './dataset/cropped/virat_kohli\\virat_kohli45.png',
#   './dataset/cropped/virat_kohli\\virat_kohli47.png',
#   './dataset/cropped/virat_kohli\\virat_kohli48.png',
#   './dataset/cropped/virat_kohli\\virat_kohli50.png',
#   './dataset/cropped/virat_kohli\\virat_kohli51.png',
#   './dataset/cropped/virat_kohli\\virat_kohli52.png',
#   './dataset/cropped/virat_kohli\\virat_kohli54.png',
#   './dataset/cropped/virat_kohli\\virat_kohli55.png',
#   './dataset/cropped/virat_kohli\\virat_kohli6.png',
#   './dataset/cropped/virat_kohli\\virat_kohli7.png',
#   './dataset/cropped/virat_kohli\\virat_kohli8.png',
#   './dataset/cropped/virat_kohli\\virat_kohli9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'lionel_messi': 0,
#  'maria_sharapova': 1,
#  'roger_federer': 2,
#  'serena_williams': 3,
#  'virat_kohli': 4}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 9.6000000e+01],
#        [ 1.2900000e+02],
#        [ 1.4100000e+02],
#        ...,
#        [-1.0435921e-02],
#        [-2.6690818e-02],
#        [-2.6696569e-03]], dtype=float32)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (172, 4096)

# %%
len(y)
# Out:
# 172

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.7441860465116279

# %%
print(classification_report(y_test, pipe.predict(X_test)))

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.798769
# 1        random_forest    0.652000
# 2  logistic_regression    0.821846
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(memory=None,
#           steps=[('standardscaler',
#                   StandardScaler(copy=True, with_mean=True, with_std=True)),
#                  ('svc',
#                   SVC(C=1, break_ties=False, cache_size=200, class_weight=None,
#                       coef0=0.0, decision_function_shape='ovr', degree=3,
#                       gamma='auto', kernel='linear', max_iter=-1,
#                       probability=True, random_state=None, shrinking=True,
#                       tol=0.001, verbose=False))],
#           verbose=False), 'random_forest': Pipeline(memory=None,
#           steps=[('standardscaler',
#                   StandardScaler(copy=True, with_mean=True, with_std=True)),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
#                                          max_depth=None, max_features='auto',
#                                          max_leaf_nodes=None, max_samples=None,
#                                          min_impurity_decrease=0.0,
#                                          min_impurity_split=None,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          n_estimators=10, n_jobs=None,
#                                          oob_score=False, random_state=None,
#                                          verbose=0, warm_start=False))],
#           verbose=False), 'logistic_regression': Pipeline(memory=None,
#           steps=[('standardscaler',
#                   StandardScaler(copy=True, with_mean=True, with_std=True)),
#                  ('logisticregression',
#                   LogisticRegression(C=1, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=100,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=None,
#                                      solver='liblinear', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False)}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.7441860465116279

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.6046511627906976

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.7441860465116279

# %%
best_clf = best_estimators['svm']

# %%
#best_clf.predict()
#best_clf.predict_proba

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 7,  0,  0,  0,  3],
#        [ 0, 10,  0,  0,  0],
#        [ 0,  3,  6,  1,  0],
#        [ 0,  1,  1,  3,  0],
#        [ 1,  0,  0,  1,  6]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict

# %% [markdown]
# ### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\rajat\anaconda3\envs\class_hop\lib\site-packages (0.14.1)
# You are using pip version 19.0.3, however version 20.2b1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
